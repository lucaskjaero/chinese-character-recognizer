# %%
from preprocessing import process_image
from dataset import CasiaML
data = CasiaML(pre_processing_function=process_image)

# %%
from tensorflow.contrib.keras.python.keras.models import Sequential
from tensorflow.contrib.keras.python.keras.layers import Conv2D, Dense, Dropout, Flatten, MaxPooling2D

from preprocessing import TARGET_HEIGHT, TARGET_WIDTH

INPUT_SHAPE = (TARGET_HEIGHT, TARGET_WIDTH, 1)

output_dimensions = 3755

model = Sequential()
model.add(Conv2D(96, kernel_size=(11, 11), strides=4, padding="same", activation='relu',
                 input_shape=INPUT_SHAPE))
model.add(MaxPooling2D(pool_size=(3, 3), strides=2, padding="valid"))
model.add(Conv2D(256, kernel_size=(5, 5), strides=1, padding="same", activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=2, padding="valid"))
model.add(Conv2D(384, kernel_size=(3, 3), strides=1, padding="same", activation='relu'))
model.add(Conv2D(384, kernel_size=(3, 3), strides=1, padding="same", activation='relu'))
model.add(Conv2D(256, kernel_size=(3, 3), strides=1, padding="same", activation='relu'))
model.add(Flatten())
model.add(Dense(output_dimensions, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(output_dimensions, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(output_dimensions, activation='softmax'))
print("Built model")

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print("Compiled model")
# Out:
# Built model
# Compiled model

# %%
BATCH_SIZE = 100
sample_count = data.sample_count
steps_per_epoch = sample_count / BATCH_SIZE
model.fit_generator(data.train_set(batch_size=BATCH_SIZE), steps_per_epoch, epochs=4)
# Out:
# Loading file: /Users/lucas/CASIA_data/HWDB1.1trn_gnt_P1/1001-c.gnt
# Epoch 1/4
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# (32, 32, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-576ddd31a1fd> in <module>()
#       2 sample_count = data.sample_count
#       3 steps_per_epoch = sample_count / BATCH_SIZE
# ----> 4 model.fit_generator(data.train_set(batch_size=BATCH_SIZE), steps_per_epoch, epochs=4)
#
# ~/anaconda/envs/chinese/lib/python3.5/site-packages/tensorflow/contrib/keras/python/keras/models.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_q_size, workers, pickle_safe, initial_epoch)
#    1079         workers=workers,
#    1080         pickle_safe=pickle_safe,
# -> 1081         initial_epoch=initial_epoch)
#    1082
#    1083   def evaluate_generator(self,
#
# ~/anaconda/envs/chinese/lib/python3.5/site-packages/tensorflow/contrib/keras/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_q_size, workers, pickle_safe, initial_epoch)
#    1877
#    1878           outs = self.train_on_batch(
# -> 1879               x, y, sample_weight=sample_weight, class_weight=class_weight)
#    1880
#    1881           if not isinstance(outs, list):
#
# ~/anaconda/envs/chinese/lib/python3.5/site-packages/tensorflow/contrib/keras/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1621         sample_weight=sample_weight,
#    1622         class_weight=class_weight,
# -> 1623         check_batch_axis=True)
#    1624     if self.uses_learning_phase and not isinstance(K.learning_phase(), int):
#    1625       ins = x + y + sample_weights + [1.]
#
# ~/anaconda/envs/chinese/lib/python3.5/site-packages/tensorflow/contrib/keras/python/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_batch_axis, batch_size)
#    1303         output_shapes,
#    1304         check_batch_axis=False,
# -> 1305         exception_prefix='model target')
#    1306     sample_weights = _standardize_sample_weights(sample_weight,
#    1307                                                  self._feed_output_names)
#
# ~/anaconda/envs/chinese/lib/python3.5/site-packages/tensorflow/contrib/keras/python/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     146                              ': expected ' + names[i] + ' to have shape ' +
#     147                              str(shapes[i]) + ' but got array with shape ' +
# --> 148                              str(array.shape))
#     149   return arrays
#     150
#
# ValueError: Error when checking model target: expected dense_3 to have shape (None, 3755) but got array with shape (100, 1)
